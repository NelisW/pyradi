# %% [markdown]
# #Triangle areas for mesh spheres
#
# This notebook calculates the area histograms for the trianguled spheres.

# %%
import numpy as np
import pyradi.ryfiles as ryfiles
import pyradi.ryplot as ryplot
import vlfd.transformations as tr

# %%
filelist = ryfiles.listFiles('.','trianglessphere*.*')
p=ryplot.Plotter(1,2,3,'Triangle area histograms',(18,12))
for subplot,filename in enumerate( filelist):
    vtxfilename = filename.replace('triangles','vertex')
    tri=np.loadtxt(filename,dtype='i4')
    vtx = np.loadtxt(vtxfilename)
    areaLst = []
    angleLst = []
    areaTot = 0
    for triangle in tri:
        length = []
        peri = 0
        for i in range(0,3):
            vtxa = vtx[triangle[i]]
            vtxb = vtx[triangle[(i+1)%3]]
            angle = tr.angle_between_vectors(vtxa,vtxb,axis=0)
            length.append(angle)
            angleLst.append(angle)
            peri += angle
            
        # from heron's theorem the planar (not spherical) area between three points 
        # is given by Area=SQRT(s(s-a)(s-b)(s-c)), where s=(a+b+c)/2 or perimeter/2.
        s = peri/2
        area = np.sqrt(s * (s-length[0])  * (s-length[1])  * (s-length[2]) )
        areaLst.append(area )
        areaTot += area
     
    areaA = np.asarray(areaLst)
    hist,bins= np.histogram(areaA, bins=100)
    binc = bins[:-1]+np.diff(bins)
    agvArea = np.mean(areaA)
    agvAngle = 180 * np.mean(angleLst) / np.pi
    binc = binc / agvArea
    
    print('{0:10s} avg area={2:.2e} tot area error={1:.4f}% Resolution={3:.3f}'.format(vtxfilename,
         100*(4-(areaTot/np.pi)),agvArea,agvAngle))
        
    if(subplot > 1 and subplot < 8):
        ptitle = '{0} (TriArea={1:.4e})'.format(filename,agvArea)
        p.plot(subplot-1,binc,hist,xlabel='Normalised area',ylabel='Count',ptitle=ptitle)
     
p.saveFig('triangleareas.eps')
# Out:
# vertexsphere_0_12.txt avg area=5.31e-01 tot area error=62.0965% Resolution=63.435
# vertexsphere_1_42.txt avg area=1.50e-01 tot area error=17.6954% Resolution=33.859
# vertexsphere_2_162.txt avg area=3.88e-02 tot area error=4.5677% Resolution=17.216
# vertexsphere_3_642.txt avg area=9.79e-03 tot area error=1.1510% Resolution=8.644
# vertexsphere_4_2562.txt avg area=2.45e-03 tot area error=0.2883% Resolution=4.327
# vertexsphere_5_10242.txt avg area=6.13e-04 tot area error=0.0721% Resolution=2.164
# vertexsphere_6_40962.txt avg area=1.53e-04 tot area error=0.0180% Resolution=1.082
# vertexsphere_7_163842.txt avg area=3.83e-05 tot area error=0.0045% Resolution=0.541

# %% [markdown]
# Evidently the total surface error is relatively small for spheres with large number of vertices, but the area distribution is slightly skew around the average value, towards smaller areas.
